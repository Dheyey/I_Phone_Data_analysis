# %%
import pandas as pd

# %%
#Read the iphone.csv dataset to pandas dataframe
idata = pd.read_csv('iphone.csv')

# %%
#1 - The column names have spaces . rename the column names to have underscore '_' instead of space (try to do in one go instead of specifying each column nam in rename method)

idata.columns = idata.columns.str.replace(' ', '_')

# %%
idata['Number_Of_Ratings'] = idata['Number_Of_Ratings'].fillna(idata['Number_Of_Ratings'].mean())

# %%
idata['Star_Rating'] = idata['Star_Rating'].fillna(idata.groupby('Ram')['Star_Rating'].transform('mean'))

# %%
idata['Discount_Percentage'] = ((idata['Mrp']-idata['Sale_Price'])/idata['Mrp']) * 100
idata
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
idata.sort_values(by ='Discount_Percentage' , ascending= False).head(1)
# Out:
#                                    Product_Name  \
# 18  APPLE iPhone 11 Pro (Midnight Green, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 18  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple       74999
#
#        Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 18  106600               7088                523  MOBFKCTSN3TG3RFJ
#
#     Star_Rating   Ram  Discount_Percentage
# 18          4.6  4 GB            29.644465

# %%
idata['Ram'].value_counts()
# Out:
# 4 GB    29
# 6 GB    19
# 2 GB    13
# 3 GB     1
# Name: Ram, dtype: int64

# %%
idata.sort_values(by ='Number_Of_Reviews' , ascending= False).head(5)
# Out:
#                        Product_Name  \
# 23  Apple iPhone SE (White, 256 GB)
# 53  APPLE iPhone SE (Black, 128 GB)
# 55    APPLE iPhone SE (Red, 128 GB)
# 57   APPLE iPhone SE (Black, 64 GB)
# 52   APPLE iPhone SE (White, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 23  https://www.flipkart.com/apple-iphone-se-white...  Apple       44999
# 53  https://www.flipkart.com/apple-iphone-se-black...  Apple       34999
# 55  https://www.flipkart.com/apple-iphone-se-red-1...  Apple       34999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
#
#       Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 23  54900              95909               8161  MOBFRFXHPZCHAPEH
# 53  44900              95909               8161  MOBFWQ6BHUEVZPXD
# 55  44900              95909               8161  MOBFWQ6BJTVFKPEJ
# ...

# %%
Price_diff = idata['Mrp'].max() - idata['Mrp'].min()
Price_diff
# Out:
# 110000

# %%
idata.sort_values(by ='Mrp' , ascending= False).reset_index().iloc[2]
# Out:
# index                                                                 21
# Product_Name                APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# Product_URL            https://www.flipkart.com/apple-iphone-11-pro-m...
# Brand                                                              Apple
# Sale_Price                                                        117900
# Mrp                                                               140300
# Number_Of_Ratings                                                   7088
# Number_Of_Reviews                                                    523
# Upc                                                     MOBFKCTSSJCWYGCC
# Star_Rating                                                          4.6
# Ram                                                                 4 GB
# Discount_Percentage                                            15.965788
# Name: 2, dtype: object

# %%
idata
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
def extract_color(product_name):
    # Split the product name by '(' and ')' to get parts within parentheses
    parts = product_name.split('(')
    if len(parts) > 1:
        # Check if the second part contains a comma (,) to identify color
        color_part = parts[1].strip()
        if ',' in color_part:
            color = color_part.split(',')[0].strip()
            return color
    return None

# %%
idata['Color'] = idata['Product_Name'].apply(extract_color)

# %%
idata
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
def extract_c(Produ):
    parts = Produ.split('(')
    right = parts[1].split(',')
    color = right[0]
    return color

# %%
idata['Color1'] = idata['Product_Name'].apply(extract_c)

# %%
idata
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
idata['Color'].value_counts()
# Out:
# Black             10
# White             10
# Silver             7
# Gold               6
# Space Grey         6
# Red                5
# Midnight Green     4
# Pacific Blue       4
# Graphite           4
# Blue               2
# RED                1
# Coral              1
# Green              1
# Purple             1
# Name: Color, dtype: int64

# %%
def extract_model(product_name):
    parts = product_name.split(' ')
    model_name = ' '.join(parts[1:3])
    return model_name

# %%
idata['model_name'] = idata['Product_Name'].apply(extract_model)

# %%
idata
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
idata['model_name'].value_counts()
# Out:
# iPhone 12    26
# iPhone 11    16
# iPhone 8      8
# iPhone SE     6
# iPhone XR     5
# iPhone XS     1
# Name: model_name, dtype: int64
